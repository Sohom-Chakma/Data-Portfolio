# %% [markdown]
# <a href="https://colab.research.google.com/github/Sohom-Chakma/Data-Portfolio/blob/main/Steam_Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Context
# Steam is the world's most popular PC Gaming hub, with over 6,000 games and a community of millions of gamers. With a massive collection that includes everything from AAA blockbusters to small indie titles, great discovery tools are a highly valuable asset for Steam. How can we make them better?
#
# # Content
# This dataset is a list of user behaviors, with columns: user-id, game-title, behavior-name, value. The behaviors included are 'purchase' and 'play'. The value indicates the degree to which the behavior was performed - in the case of 'purchase' the value is always 1, and in the case of 'play' the value represents the number of hours the user has played the game.

# %%
import pandas as pd

df = pd.read_csv('Steam Sales Data.csv')

df
# Out:
#            UserID                       Title Count Type  Count
# 0       151603712  The Elder Scrolls V Skyrim   purchase    1.0
# 1       151603712  The Elder Scrolls V Skyrim       play  273.0
# 2       151603712                   Fallout 4   purchase    1.0
# 3       151603712                   Fallout 4       play   87.0
# 4       151603712                       Spore   purchase    1.0
# ...           ...                         ...        ...    ...
# 199995  128470551                 Titan Souls       play    1.5
# 199996  128470551  Grand Theft Auto Vice City   purchase    1.0
# 199997  128470551  Grand Theft Auto Vice City       play    1.5
# 199998  128470551                        RUSH   purchase    1.0
# 199999  128470551                        RUSH       play    1.4
#
# [200000 rows x 4 columns]

# %%
df.shape
# Out:
# (200000, 4)

# %%
df.info()

#no null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   UserID      200000 non-null  int64
#  1   Title       200000 non-null  object
#  2   Count Type  200000 non-null  object
#  3   Count       200000 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.1+ MB

# %%
df.describe()
# Out:
#              UserID          Count
# count  2.000000e+05  200000.000000
# mean   1.036559e+08      17.874384
# std    7.208074e+07     138.056952
# min    5.250000e+03       0.100000
# 25%    4.738420e+07       1.000000
# 50%    8.691201e+07       1.000000
# 75%    1.542309e+08       1.300000
# max    3.099031e+08   11754.000000

# %%
df.values
# Out:
# array([[151603712, 'The Elder Scrolls V Skyrim', 'purchase', 1.0],
#        [151603712, 'The Elder Scrolls V Skyrim', 'play', 273.0],
#        [151603712, 'Fallout 4', 'purchase', 1.0],
#        ...,
#        [128470551, 'Grand Theft Auto Vice City', 'play', 1.5],
#        [128470551, 'RUSH', 'purchase', 1.0],
#        [128470551, 'RUSH', 'play', 1.4]], dtype=object)

# %%
#Removing 'purchase' in type column because it's not relevent.
df = df[df['Count Type'] != 'purchase']
df
# Out:
#            UserID                       Title Count Type  Count
# 1       151603712  The Elder Scrolls V Skyrim       play  273.0
# 3       151603712                   Fallout 4       play   87.0
# 5       151603712                       Spore       play   14.9
# 7       151603712           Fallout New Vegas       play   12.1
# 9       151603712               Left 4 Dead 2       play    8.9
# ...           ...                         ...        ...    ...
# 199991  128470551                Fallen Earth       play    2.4
# 199993  128470551                 Magic Duels       play    2.2
# 199995  128470551                 Titan Souls       play    1.5
# 199997  128470551  Grand Theft Auto Vice City       play    1.5
# 199999  128470551                        RUSH       play    1.4
#
# [70489 rows x 4 columns]

# %%
#drop entire type column and rename 'count' column to Hrs Played
#axis=1 perform operation on entire columns, axis=0 for rows
df = df.drop('Count Type', axis = 1)
df = df.rename(columns={'Count':'Hrs Played'})
df
# Out:
#            UserID                       Title  Hrs Played
# 1       151603712  The Elder Scrolls V Skyrim       273.0
# 3       151603712                   Fallout 4        87.0
# 5       151603712                       Spore        14.9
# 7       151603712           Fallout New Vegas        12.1
# 9       151603712               Left 4 Dead 2         8.9
# ...           ...                         ...         ...
# 199991  128470551                Fallen Earth         2.4
# 199993  128470551                 Magic Duels         2.2
# 199995  128470551                 Titan Souls         1.5
# 199997  128470551  Grand Theft Auto Vice City         1.5
# 199999  128470551                        RUSH         1.4
#
# [70489 rows x 3 columns]

# %%
df_duplic = df.duplicated()

print(df[df_duplic])

# no duplicates so I continue using df
# Out:
# Empty DataFrame
# Columns: [UserID, Title, Hrs Played]
# Index: []

# %%
print(df.isnull().any())

#no null values
# Out:
# UserID        False
# Title         False
# Hrs Played    False
# dtype: bool

# %%
#Create input set to predict Title of c
#from sklearn.tree import DecisionTreeClassifier

#X = df.drop(columns=['Title'])
#y = df['Title']

#model = DecisionTreeClassifier()

#model.fit(X, y)

#prediction = model.predict([  [198890, 50], [123312, 200 ]  ])

#prediction

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

X = df.drop(columns=['Title'])
y = df['Title']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

model = DecisionTreeClassifier()
model.fit(X_train, y_train)

prediction2 = model.predict(X_test)

score = accuracy_score(y_test, prediction2)
score
# Out:
# 0.02125124131082423

# %% [markdown]
# Low accuracy
